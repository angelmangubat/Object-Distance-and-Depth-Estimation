# %% [markdown]
# **Name**: Angelique Mangubat
#
# **Affiliation**: Atlantic Technological University
#
# **Assignment 02**: Multiple View Geometry Computer Vision and Modelling Simulation and Test

# %%
#Map google drive and the input and output files
from google.colab import drive
drive.mount('/content/drive')
INPUT = "/content/drive/My Drive/App/MVGCV/depth/output_0.5sec_interval/test1/"
OUTPUT = "/content/drive/My Drive/App/MVGCV/depth/output_0.5sec_interval/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import glob
import cv2
 
img_array = []
for filename in glob.glob(INPUT+'*.jpg'):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    img_array.append(img)
 

#out = cv2.VideoWriter(OUTPUT+'scenario1.avi',cv2.VideoWriter_fourcc(*'DIVX'), 15, size)
out = cv2.VideoWriter(OUTPUT+'scenario1.mp4',cv2.VideoWriter_fourcc(*'DIVX'), 10, size)
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
