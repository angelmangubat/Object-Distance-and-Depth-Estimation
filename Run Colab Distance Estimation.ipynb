# %% [markdown]
# **Name**: Angelique Mangubat
#
# **Affiliation**: Atlantic Technological University
#
# **Assignment 02**: Multiple View Geometry Computer Vision and Modelling Simulation and Test

# %% [markdown]
# Reference: https://github.com/RmdanJr/vehicle-distance-estimation

# %%
#Map google drive and the input and output files
from google.colab import drive
drive.mount('/content/drive')
PATH = "/content/drive/My Drive/App/MVGCV/distance/"
# %cd '/content/drive/My Drive/App/MVGCV/distance/'

# %%
# !git clone https://github.com/RmdanJr/vehicle-distance-estimation.git

# %%
# %cd vehicle-distance-estimation/distance-estimator/

# %%
# !pip install -r requirements.txt

# %%
# !bash scripts/download-kitti-dataset.sh

# %%
# !bash scripts/organize-dataset-format.sh

# %%
import os
# !python generate-csv.py --input=kitti-dataset/train_annots/ --filename=annotations.csv --results .

# %%
# !pip install tensorrt

# %%
#!python training_continuer.py --model models/model@1535477330.json --weights models/model@1535477330.h5 --results models/ --train train.csv --test test.csv

# %%
#!python training_continuer.py --results models/ --train train.csv --test test.csv
# !python train.py --results models/ --train train.csv --test test.csv

# %%
# !pwd

# %%
import os
import csv
# !ls

# %%
# !python inference.py --data data.csv --model models/model@1535470106.json --weights models/model@1535470106.h5 --results .

# %%
# !python visualizer.py --data "/results_movie3/data/data.csv" --frames "/results_movie3/results/frames/" -fps 90 --results results
